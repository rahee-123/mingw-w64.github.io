# %% [markdown]
# <a href="https://colab.research.google.com/github/rahee-123/mingw-w64.github.io/blob/main/Data_Cleaning_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Potentials File

# %%
import numpy as np
import pandas as pd

# %%
potential_df =pd.read_csv("/content/Potential (1).csv")
potential_df
# Out:
#                             lead_name status_label primary_contact_name  \
# 0           Marine Specialty Painting    Potential   Alfred Marchigiani
# 1      J Buote Painting Company, Inc.    Potential          James Buote
# 2        Mottos Painting & Fine Fnshs    Potential           Eric Motto
# 3      New World Paint & Handyman Llc    Potential        Avelcio Nunez
# 4         McDowell Construction, Inc.    Potential          Ed McDowell
# ...                               ...          ...                  ...
# 31051                   Spencer Blair    Potential        Spencer Blair
# 31052                     Robert Watt    Potential          Robert Watt
# 31053   Russ Hall Floorcovering, INC.    Potential            Russ INC.
# 31054                 Rupp Consulting    Potential         Kenneth Rupp
# 31055                         clint m    Potential              clint m
#
#       primary_contact_first_name primary_contact_last_name  \
# ...

# %% [markdown]
# **null values count**

# %%
potential_df.isna().sum()
# Out:
# lead_name                                15
# status_label                              0
# primary_contact_name                    408
# primary_contact_first_name              411
# primary_contact_last_name               412
# primary_contact_title                 15185
# primary_contact_primary_phone          3492
# primary_contact_primary_phone_type     3492
# primary_contact_primary_email           151
# Email Group Number                        0
# dtype: int64

# %%
df_clean = potential_df.dropna()
df_clean
# Out:
#                                lead_name status_label primary_contact_name  \
# 0              Marine Specialty Painting    Potential   Alfred Marchigiani
# 2           Mottos Painting & Fine Fnshs    Potential           Eric Motto
# 3         New World Paint & Handyman Llc    Potential        Avelcio Nunez
# 5          A Finishing Touch Painting Co    Potential       Michael Comora
# 12             R&E Drywall Solutions LLC    Potential         Julio Torres
# ...                                  ...          ...                  ...
# 30985  AC Electric Company - Bakersfield    Potential        Dan Alexander
# 30986      Absolute Drywall Construction    Potential       Miguel Delgado
# 30988     Abrishay Construction Services    Potential           Bart Block
# 30989                    ABM Landscaping    Potential    Mr Patrick Malone
# 30990           ABM Electric Corporation    Potential         Vince Milnik
#
#       primary_contact_first_name primary_contact_last_name  \
# ...

# %%
potential_new = df_clean
potential_new.to_csv("Cleaned potential.csv")

# %% [markdown]
# # Potential 2

# %%
df = pd.read_csv("/content/Potential 2 (1).csv")
df
# Out:
#                               lead_name status_label primary_contact_name  \
# 0                         Cache Roofing    Potential       Cynthia Paquet
# 1                          Metro Piping    Potential          Steven Lowe
# 2                 Intermountain Drywall    Potential         Gary Douthit
# 3               G.I.A. PAINTING COMPANY    Potential         Derek Miller
# 4            Circle C Contracting, Inc.    Potential         Charlie Barr
# ...                                 ...          ...                  ...
# 19976               Exclusive Exteriors    Potential                 Tony
# 19977            John Rogers Renovation    Potential        Nicola Rogers
# 19978  Blueprint Painting & Renovations    Potential       Brandon Beaver
# 19979             Kreedman Construction    Potential        Mark Kreedman
# 19980                      PMC Painting    Potential            Jim Drown
#
#       primary_contact_first_name primary_contact_last_name  \
# ...

# %% [markdown]
# **null values count**

# %%
df.isna().sum()
# Out:
# lead_name                               703
# status_label                              0
# primary_contact_name                     42
# primary_contact_first_name               42
# primary_contact_last_name                42
# primary_contact_title                  2358
# primary_contact_primary_phone           424
# primary_contact_primary_phone_type      424
# primary_contact_other_phones          11945
# primary_contact_primary_email           606
# Email Group Number                        0
# dtype: int64

# %%
clean_potential2 = df.dropna()
clean_potential2
# Out:
#                                  lead_name status_label primary_contact_name  \
# 1                             Metro Piping    Potential          Steven Lowe
# 18                                 Drywall    Potential       Paula Levesque
# 21                     Fresh Coat Painters    Potential       Valerie Traore
# 26                      Platinum Landscape    Potential       Cherie Johnson
# 28                      LIFESTYLE PAINTING    Potential        Peter Schramm
# ...                                    ...          ...                  ...
# 19818                    Green Environment    Potential           Mark Green
# 19891  Marin Wood Restoration and Painting    Potential         Paul Burrous
# 19892      Advance Construction Technology    Potential     Robert Rosenberg
# 19894            Donn Roberts Construction    Potential         Donn Roberts
# 19898       Ray Tech Professional Painting    Potential     Raymond Techaira
#
# ...

# %%
clean_potential2.to_csv("clean_potential2.csv")

# %% [markdown]
# # **Cstomers Dataset**

# %%
df = pd.read_csv("/content/Customers (2).csv")
df
# Out:
#                               lead_name               status_label  \
# 0                  Dent Turner AC Sales                   Customer
# 1           Jeff Co Flooring and Supply                   Customer
# 2                         Rogo Builders                   Customer
# 3    General Services and Marketing Inc                   Customer
# 4                      Get Floored, LLC                   Customer
# ..                                  ...                        ...
# 553                  NCJ Painting, Inc.  Customer - Ryan Manocchio
# 554                   Hendrick Painting  Customer - Ryan Manocchio
# 555                        360 Painting  Customer - Ryan Manocchio
# 556                 Colorcraft Painting  Customer - Ryan Manocchio
# 557             ConcreteCare of Atlanta  Customer - Ryan Manocchio
#
#     primary_contact_name primary_contact_first_name primary_contact_last_name  \
# 0            Dent Turner                       Dent                    Turner
# ...

# %%
df.isna().sum()
# Out:
# lead_name                               0
# status_label                            0
# primary_contact_name                    6
# primary_contact_first_name              6
# primary_contact_last_name               6
# primary_contact_title                 413
# primary_contact_primary_phone          63
# primary_contact_primary_phone_type     63
# primary_contact_other_phones          472
# primary_contact_primary_email           5
# primary_contact_other_emails          537
# Email Group Number                      0
# dtype: int64

# %%
clean_file = df.dropna()
clean_file
# Out:
#              lead_name status_label primary_contact_name  \
# 6    Heritage Builders     Customer         Jenna Decker
# 359  SERG PAINTING LLC     Customer      Sergio Huidobro
# 490        G2 Surfaces     Customer       Greg Kametches
#
#     primary_contact_first_name primary_contact_last_name  \
# 6                        Jenna                    Decker
# 359                     Sergio                  Huidobro
# 490                       Greg                 Kametches
#
#     primary_contact_title primary_contact_primary_phone  \
# 6           Sales Support               +1 732-455-9159
# 359                 Owner               +1 410-320-6490
# 490               Manager               +1 770-257-7356
#
#     primary_contact_primary_phone_type  \
# 6                               mobile
# 359                             mobile
# 490                             mobile
#
#                      primary_contact_other_phones  \
# 6                           +17328130298 (direct)
# ...

# %%
clean_file.to_csv("clean_Customers.csv")

# %% [markdown]
# # **Interested File**

# %%
df= pd.read_csv("/content/Interested (1).csv")
df
# Out:
#                            lead_name status_label primary_contact_name  \
# 0                    Denali Snow Cat   Interested         Zack Russell
# 1        Naylor Landscape Management   Interested         Brad Battell
# 2            Williamson Construction   Interested     Brian Williamson
# 3                   RNB Flooring Inc   Interested      Barry Patterson
# 4               ML STRAIGHT PAINTING   Interested         Oscar Sierra
# ..                               ...          ...                  ...
# 901          TOP FLIGHT BUILDERS LLC   Interested      Zach Cunningham
# 902          Reach Development Group   Interested       Brandon Martin
# 903   ECE Design BuildPrivacy Policy   Interested          Matt Hansen
# 904  Architectural Interior Products   Interested         Justin Huber
# 905                       Okin Pivot   Interested       Niko Calliagas
#
#     primary_contact_first_name primary_contact_last_name  \
# ...

# %%
df.isna().sum()
# Out:
# lead_name                               6
# status_label                            0
# primary_contact_name                   17
# primary_contact_first_name             17
# primary_contact_last_name              17
# primary_contact_title                 636
# primary_contact_primary_phone          21
# primary_contact_primary_phone_type     21
# primary_contact_other_phones          828
# primary_contact_primary_email           6
# Email Group Number                      0
# dtype: int64

# %%
clean_interested = df.dropna()
clean_interested
# Out:
#                                       lead_name status_label  \
# 15                            The Pros Painting   Interested
# 19                            Verafloor Systems   Interested
# 71                   Bryant Hartke Construction   Interested
# 86                              Florida Drywall   Interested
# 102          Trinity Painting and Wall Covering   Interested
# 104                      BLUE MOUNTAIN BUILDERS   Interested
# 108                      M-13 Construction Inc.   Interested
# 113                      Milestone Construction   Interested
# 133              Sustainable Modular Management   Interested
# 153                    McGillivray Construction   Interested
# 163                      Eco Building Solutions   Interested
# 185                                      BluCAL   Interested
# 191                              MSG Associates   Interested
# 193                       Superior Wall Systems   Interested
# ...

# %%
clean_interested.to_csv("clean_interested.csv")

# %% [markdown]
# # **Paid Leads from information refine**

# %%
df = pd.read_csv("/content/Paid Leads from Information Refinery 13Aug2019 (1).csv")
df
# Out:
#      First Name  Last Name              Title                   Company Name  \
# 0          Paul      Corey          President          Johnson Acoustics Inc
# 1        Robert  Buonopane  Executive Officer                         Bonaco
# 2      Philip E      Chick       Board Member            Fine Line Interiors
# 3          Tony   Giordano              Owner            American Acoustical
# 4         Kevin      White     Vice President                   Cheviot Corp
# ...         ...        ...                ...                            ...
# 9177      Griff     Rausch          President  Engineered Wall System/stexas
# 9178    Normand   Marchand              Owner                Clear Wall Corp
# 9179      Nancy     Taylor       Board Member           Miller Spray Svc Inc
# 9180     Joseph      Remes          President        Prime Time Painting Inc
# 9181       Matt     Hudson              Owner               Protect-a-shield
#
# ...

# %%
df.isna().sum()
# Out:
# First Name               0
# Last Name                0
# Title                    0
# Company Name             0
# Address                  0
# City                     0
# State                    0
# Zip Code                 0
# Phone Number           120
# Email                    0
# Status                   0
# Trade                    0
# Company Sales           33
# Number of Employees      2
# Email Group Number       0
# dtype: int64

# %%
PLFIR = df.dropna()
PLFIR.to_csv("Cleaned_Paid_Lead_from_information_refine.csv")

# %% [markdown]
# # **Stack Software Sold**

# %%
df = pd.read_csv("/content/Stack Software Sold.csv")
df
# Out:
#              Contact Name                                     Company Name  \
# 0     Haralambos Tsivicos                        Tsivicos Enterprises, Inc
# 1            Dustin Smith         Smith Development & Construction Company
# 2              Mark Sarno  Esi Waterproofing And Masonry Restoration. Inc.
# 3       Justin VonderHaar                               VonderHaar Masonry
# 4              Mark Sarno  Esi Waterproofing And Masonry Restoration. Inc.
# ...                   ...                                              ...
# 1155      David Schindler                                 Allied Interiors
# 1156           Mary Miano                               Dirtt By Gl Seaman
# 1157           Will Oliva                          Level Five Construction
# 1158       Robbie Phillps                American Stucco, Precast, & Stone
# 1159        Jesse Aguirre                             Millennium Interiors
#
#                                    Email  \
# ...

# %%
df.isna().sum()
# Out:
# Contact Name           169
# Company Name             0
# Email                    7
# Trade                   27
# Phone Number             2
# #Email Group Number      0
# dtype: int64

# %%
clean_SS = df.dropna()
clean_SS.to_csv("Clean_Software_Sold1.csv")

# %% [markdown]
# # **Stack Software Sold 2**

# %%
df = pd.read_csv("/content/Stack Software Sold 2.csv")
df
# Out:
#          Contact Name                                      Company Name  \
# 0          Rick Peevy                      Genesis Integrated Solutions
# 1      robert jakubek                      Spray Foam International Inc
# 2      Warren Murdock                Lynn Douglas Design & Construction
# 3       Chad Matthews                      Lewis Roofing & Construction
# 4                 NaN                               All American Siding
# ...               ...                                               ...
# 1114   Milos  Nikolic                                Nikom Construction
# 1115    Jennifer Gill                 Exact Match Masonry Staining, LLC
# 1116  douglas beasley  Young & Meathe Homes & Heirloom Building Company
# 1117              NaN                          Golden Floor Preparation
# 1118      David Bryan                                   Keyturn Network
#
#                                   Email        Location     Phone Number  \
# ...

# %%
df.isna().sum()
# Out:
# Contact Name            246
# Company Name              0
# Email                     2
# Location                  9
# Phone Number              0
# # Email Group Number      0
# dtype: int64

# %%
SSSold = df.dropna()
SSSold.to_csv("Stack_Software_Sold_2.csv")

# %% [markdown]
# **B STACK Construction Technologies lead 9306 kb file**

# %% [markdown]
# **All the File is junk or useless**

# %%
df = pd.read_csv("/content/B STACK Construction Technologies leads 2017-07-27 19-40.csv")
df
# Out:
# <ipython-input-36-5ffe69a3ff32>:1: DtypeWarning: Columns (26,37,38,39,41,43,45,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/B STACK Construction Technologies leads 2017-07-27 19-40.csv")
#                                                     id  \
# 0     lead_ClE9WJJfJQamxL7k7gMRlsQK5y3uMPxjLE2IzfxQy6L
# 1     lead_ZQbnhp1DsslzG6RLbPpmzLceNdFtTbkdyobzR5im4Jp
# 2     lead_ch7VsRMq0vrEjb38KwtWNlEc91ygIeLFbCK8aiZx0P7
# 3     lead_t1EmkmhSNzJfAUy9EtlvhP4VhuHeLwdQF3v3wYSnrkf
# 4     lead_dlt3U4sWrAIEsnpqvG5NjlA9HEH7CMsSZwYZnQSbxOb
# ...                                                ...
# 5268  lead_PyoJLFs0tdd3PqXCjImyJtbxeC4eXQdUXSyVHshycmh
# 5269  lead_s4AI6AeXsfPNv44Pba1NPoBxmO045Oy7MlkhWLcEFU5
# 5270  lead_LQFc7A6RUEu1q6AriFt930Gm73hcdLitmHFQsCCu4Jn
# 5271  lead_PU4ZDGERhnSOeHt8IFeIl5nodcr5IoxGzU2Vi5D68nd
# 5272  lead_XJcqJ0WYDkNXdUSUJS6uHkfzW7ffcanHKpegn9QkBe4
#
# ...

# %%
df.isna().sum()
# Out:
# id                                          0
# display_name                                0
# lead_name                                 554
# description                              4961
# url                                      3062
#                                          ...
# total_one_time_lost_opportunity_value    5223
# total_one_time_opportunity_value         4916
# total_one_time_won_opportunity_value     5247
# total_opportunity_value_summary          4566
# won_opportunity_value_summary            4943
# Length: 249, dtype: int64

# %%
clean_data = df.dropna()
clean_data
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# # **B STACK Construction Technologies lead**

# %%
df = pd.read_csv("/content/B STACK Construction Technologies leads 2017-07-27 19-39.csv")
df
# Out:
# <ipython-input-39-987db94f5bcf>:1: DtypeWarning: Columns (27,35,41,47,77,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/B STACK Construction Technologies leads 2017-07-27 19-39.csv")
#                                                     id  \
# 0     lead_W7t2NzhGZbwXQADRT0kcLpchds4puZkVLdHrFzKOuy4
# 1     lead_LW9YGp0jvfjKbyuQsiUnP1RDRjr9ghpMkDhTE4XPlYt
# 2     lead_t8MCNnXTMWuKfGLwdhCfFO2xRW6VSXM0HVLgEPZPCvw
# 3     lead_xMaPbxMtc18gB78KDAgDxQ008oP4sWMerYjv2CUbJZS
# 4     lead_m9xJIv7SxUbj0lp4YJWl2bAs6p1d7PH6oMHOaSRvY8D
# ...                                                ...
# 9850  lead_4ow7IUXznJM4rI3OzCrLPmV30a7dBAaZWiQxDe1lwUe
# 9851  lead_KBuYKSWCnz8xJNnWZ9XPTtblSfLQwoT6mFvGw9JENAT
# 9852  lead_E0TQG79CZIqZe1ieEXm04VT8Ioe6QC2JzC1RKvsyjAx
# 9853  lead_I21YoFd3xVDp6TblOpkSAtZpIT7rhPzB8j4F2U03Uff
# 9854  lead_DBTKMvmVhzktlgQlPhMPBIbgzQ3nwYSKcVBFxXUnRzG
#
#                                display_name  \
# ...

# %%
df.isna().sum()
# Out:
# id                                          0
# display_name                                2
# lead_name                                 242
# description                              9694
# url                                      4108
#                                          ...
# total_one_time_lost_opportunity_value    9756
# total_one_time_opportunity_value         9595
# total_one_time_won_opportunity_value     9853
# total_opportunity_value_summary          9377
# won_opportunity_value_summary            9836
# Length: 249, dtype: int64

# %%
df.dropna()
# Out:
# Empty DataFrame
# ...
